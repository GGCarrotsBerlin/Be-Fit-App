# %% [markdown]
# ### Crawl google Places data

# %%
import requests
import time
import json
import numpy as np
from elasticsearch import Elasticsearch, client

# %%
berlin_coords = (52.52426800, 13.406290)
# Coordinates of a bbox centered in Berlin
nw = (52.58363, 13.2035)
se = (52.42755, 13.62648)
# Out:
# (52.42755, 13.2035)

# %%
# Box is ~30km x 20km. Sample every ~1 km
cnt_x = 40
cnt_y = 25

# %%
x = np.linspace(nw[0], se[0], cnt_x)
y = np.linspace(nw[1], se[1], cnt_y)

# %%
# Relevant types for places related to health and fitness
types = ['park', 'gym', 'doctor', 'health', 
         'hospital', 'pharmacy', 'physiotherapist', 'spa']

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
headers = {'Content-Type': 'application/json'}

params = {'location': ','.join(map(str, berlin_coords)), 
          'types': '|'.join(types),
          'rankby': 'distance',
          'key': key}
#r = requests.get(base_url, headers=headers, params=params)

# %%
r = requests.get(base_url, headers=headers, params=params)
res = r.json()
print([elem['name'] for elem in res['results']])
while 'next_page_token' in res:
    print('***Got more in this location')
    params['pagetoken'] = res['next_page_token']
    print(params)
    time.sleep(2)
    r = requests.get(base_url, headers=headers, params=params)
    res = r.json()
    print([elem['name'] for elem in res['results']])
# Out:
# ['ic! berlin Flagship Store', 'Dr. med. Christoph Nimsgern', 'Brillenwerkstatt Berlin-Mitte', 'Dr.med. Christiane Handrick', 'Spirit Yoga Studio Mitte', 'Sanft wie Seide - Tantra, Tantramassagen und mehr in Berlin', 'dm-drogerie markt', 'Neptun Apotheke', 'Zentrum für Traditionelle Chinesische und Integrative Medizin Berlin', 'Dr. med. dent. Ulrike Heintzenberg', 'Frau Dr. med. Martina Müngersdorf', 'Fit am Rosenthaler Platz', 'Bodystreet Berlin Monbijouplatz', 'Longma 2 Thaimassage', 'Senzera Waxing Studio', 'Peilin - Thaimassage', 'Bikram Yoga Berlin-Mitte', 'Pro Seniore Residenz Vis à vis der Hackeschen Höfe', 'Praxis für Physiotherapie und Handrehabilitation', 'Praxis Annekatrin Tschörtner']
# ***Got more in this location
# {'location': '52.524268,13.40629', 'types': 'park|gym|doctor|health', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CpQCDgEAAPMHT4P-V04BSm8QmLCqP6i7x8vNGzlGpjp7QglbZTq2dNy1N---3EOp_UUYcBQcpyImvYBp4d-WAOZM-v8hnonHJ3JQvoD1HGGuLItN39Yutj5W2kVMbxFQOQvOSFZx5VuIDw5UkdAfFx_g83YnTEhZaq5X5xyKYVbX9i1HnELbY2X93jmrgmHv6k6r7nBzn_UsTH9ZcnSCwMp5tPD7BuqRT8NFlHcZbIljU-a9CER2vZjSsBZgAtW-ZZTyH8U3LGZEIhRTGhU00yvYbSHFK2WTlofsfOelHYj1YsiFGhwSYcOaShCKTgde1CF_xY3n8gVEra0Q4_keG_BtrdsmQsoFDw2_7m2tB9ulzDMC-dHjEhBhlccXEq1GNEQk_pgKg69DGhSo2_zakOt4GTIQH2EKPkJ4nhHa5A', 'radius': 800}
# ['Praxis für Diagnostische Radiologie', 'Dr. med. Torsten Meyer', 'Dipl. Med. Ute Rehberg', 'Praxis für Psychotherapie - Franziska Kühne', 'Dr. med. Carla Schälicke', 'Zahnarztpraxis Herrligkoffer', 'Yi-Spa', 'Dr. med. Christian Gogoll', 'Praxisverbund Berlin Prof. Dr. O. König', 'VITALIA GmbH', 'The Different Scent Parfümerie', 'BIO COMPANY Dircksenstraße', 'Fitness First - Women Club', 'dm-drogerie markt', '"Jacob Böhme" Orthopädie-Schuhmacher GmbH', 'Praxis für Osteopathie - Fabian Fleischer D.O.®', 'Coaching Haus', 'Shotokan Kyokai Berlin Mitte', 'Kampfsportschule im Klostergarten', 'Funk Optik']
# ***Got more in this location
# {'location': '52.524268,13.40629', 'types': 'park|gym|doctor|health', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CrQDrgEAAOg3hsxMhD-PNYRCksgzAqAvDWD3_FvZd56tERUb_2uerjsGqrS0FbWxDqN1T4RQq_p6tU4CWb4eLRzreVY_bZ8bnidW-nswt9oXsmIGeAUBhsh6iesWXQv-rfRYnXmOgCcsT558rxPMFzHxL1FrBCLSmPUh33I4wHq9CVZy2mO34z67eQ4Ll_yLRMIf3jpi7Kg5nhnVGOPdKqLbGWUfiQDRThiq7zYEFN4tH2XUcpPcbc3Pvoi_mLP7Pj8fO6ytuo4UsRZE8nigaZ5Dpb7UpZsEXvb1_WIXaySJX81mcHjX73C2wJ-I1iHfi4aF3OxSfiF85_K6UBU8j1Vu5NEjEPLA-uQmFSNhtVBvOuLQLwFf0C23O99A4XdUkGJeng9_RcQn9sD_5-ZCU5LVO2G6pk7OzjIA3MUyUJ336aDgcNIBjmIgKNRZ3lEOJBvZgpyztp9Ro3RTehXhu6yAeqslkEjDi8xczT9RSAQrgNGpLSg_164wZxKlKMWkXgvcsPTgOpkg1JdFxuFZzQk2A3FZ0DbzuNJVmiaBFbESraP4Z3m-5sFsrQXrajxZblFFeSqd9hIQIpRiy5wrIrP9Dm-K2PsYeRoUlTND8Uj5l60Jbzt1gGBNaKT7G2s', 'radius': 800}
# ['Kosmetikinstitut am Hackeschen Markt - Kosmetikstudio Berlin Mitte', 'sichtwechsel® Mitte', 'BerlinApotheke Hackescher Markt', 'dm-drogerie markt', 'Herr Jürgen Ranft', 'Frau Dr. med. Ursula Blank', 'Radiologie am Rosa-Luxemburg-Platz', 'Shendao - Personal Healthcare (Praxis für Chiropraktik, Akupunktur und alternative Heilverfahren)', 'Monbijoupark', 'Panorama-Apotheke', 'Rossmann Drogeriemarkt', 'Mr. Masseur Berlin Mitte, Massage', 'Heike Röhl', 'Dr. med. Alexander Mach', 'essanelle Ihr Friseur', 'Heise Zahnartztpraxis', 'Herr Dr. med. Marcus Schneider', 'Zahnärzte Panorama1', 'Amplifon Hörgeräte', 'Medizinisches Versorgungszentrum am Rosa-Luxemburg-Platz GmbH']

# %%
params['location'] = ','.join(map(str, [x[0], y[0]]))
r = requests.get(base_url, headers=headers, params=params)
res = r.json()
print([elem['name'] for elem in res['results']])
while 'next_page_token' in res:
    print('***Got more in this location')
    params['pagetoken'] = res['next_page_token']
    print(params)
    time.sleep(2)
    r = requests.get(base_url, headers=headers, params=params)
    res = r.json()
    print([elem['name'] for elem in res['results']])
# Out:
# ['DLRG Wasserrettungsstation Bürgerablage', 'Berliner Camping Club e. V. - Platz Bürgerablage', 'Private Siedlung', 'Pflegeheim AGAPLESION BETHANIEN HAVELSTRAND', 'Pflegeteam Spandau', 'Relax-Braun', 'Logopädische Praxis', 'DKV Deutsche Krankenversicherung Klaus-Jürgen Lüpke', 'HUK-COBURG Versicherungsvermittlerin Sabine Kellermann', 'HUK-COBURG Versicherungsvermittler Harald Lohse', 'Frau Ingrid Borchert', 'Herr Dipl.-Psych. Bernd-Uwe Krause', 'Frau Dipl.-Psych. Anneke Polenski', 'HUK-COBURG Versicherungsvermittler Johannes van Look', 'HUK-COBURG Versicherungsvermittlerin Ingrid van Look', 'Yoga Bernd', 'St. Elisabeth Seniorenheim', 'Evangelisches Johannesstift SbR', 'Kurzzeitpflege Lindenhof', 'Sandra-Barbara Braun']
# ***Got more in this location
# {'location': '52.58363,13.2035', 'types': 'park|gym|doctor|health|hospital|pharmacy|physiotherapist|spa', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CsQCOgEAAMDjx3MZX0DLsW1nFxGdFm35FmWBnrWzwfLf8lgda9_tZVnWGque9wTsiF3UeHzIjUw31BE8LceyrY9OjTXLzWRL0ER49Uo_aXoZXjre9-3yZpQiKkFYflR5LPlMB2mB0HnkCzex-P7t-skOxechasROpf1W9ClYM30dZCFeH5KCTQkvYhpGoZfj8I3BbfNYC41gLH4hQxdOWhne7C6IsqUp9oxfo8IMrMZYbajv9oMBS1DYcPX_SYmWIVUH6yMgox4nmds1tRha8ilbr-LM9OTpU65XpfNaOlEMXOQjRh9rrZeYA7m63Hap3ZH_hxMR4XOaRUs9EOkqidzL6whnLbgvJ8gfOBPA1ZMb3AmB0tl4_N6GuK92EJdQYfhqVm9LIr5eWz2D0EWHHsAVpDDzhAKAUPXwQAu9uz-PqPHgtQIYEhBAYZ6dWzgD1yIn8zmZjrTfGhTFduX3xlivA1sLr8vxyBPo1xayqA', 'rankby': 'distance'}
# ['Maiko Lüben - fit29 Personal Training', 'Feel Good - Massagen in Berlin-Spandau', 'Tagespflege Hanna im Evangelischen Johannesstift', 'Therapiezentrum Alte Schule', 'Adrienne Gängler - Praxis für Logopädie', 'Sabine Kessler-Jorcke und Petra Schmidt', 'Fit im Essen Ernährungs- Beauty- und Wellnesscoaching', 'Dr. med. Andreas von Criegern', 'Dr. med. Mirijam Bader-Holl', 'Praxis für Allgemeinmedizin am Falkenplatz', 'Steffen Rothkegel Facharzt für Allgemeinmedizin', 'Christel Kammer', 'Seniorenzentrum Caroline Bertheau', 'Frau Dr. Wahlkammer', 'DLRG Wasserrettungsstation Sandhausen', 'Wichern-Krankenhaus', 'Amalie-Sieveking Haus', 'Physotherapie Am Theodor-Heuß-', 'Pension Weimann', 'Heymann-Mönnikes Ingeborg Psychotherapie']
# ***Got more in this location
# {'location': '52.58363,13.2035', 'types': 'park|gym|doctor|health|hospital|pharmacy|physiotherapist|spa', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CuQD2gEAAONmfJFnny43Jmp9_vMCvshOQxD2HEyUFHZuQ_9NIuOkjQvBVtYd3a0R-3kXX0W-c0jGSWDe_EUiZJ4JP32WrfQJE4m7Z6jPb2nqpisxfetzmdXyKuJXcE2B3imgP3HzsE6zmzXTRHS_asATHmKHrwhdbShfCW4Sg0yIAxRWMhd70J7B9nGc4G6SZF-BVLLBoxk_G3yS6pkh9CILo5nforfQ6zj4r_l1rd7u3id_hEmg90ON3a3h3LCcDbMrO5T97pPtUPqFazRQX-PjNikScDUGtBQe-N47VAqUGqDqd3ukugsAV-9ntht7ISHSUC4K7IOcA9i928MqOAYiYMB6K1ZLiBQMaM3rTPsmhk-DMaJ3fkmgSYLHn2IZlOpXbzAUp2Mswr5bU8VnDwLDkBzSdMMqxppF31womLEHOBole04bt91YPGzzucYGbwlAU7iELgE6fb1vGibEvowCPGNaafZQX4vIAcUA8fVh9vFCaGPbsL5AAl4UNcXPwuc2JxoRV_l9lDeddfrmO103y8QulLBnxQhZZRS7q4wu7oyv884RNRdrkQaUJzk2LOI4b8ZZtwjjfY0XhMrvc3EFgv0D64OHtGmYKNF3JluaJAOgxnPwB5i7xoGpG4M3vJoEo2CpDhIQbfRsAjzo12TM5qSyNCA1xxoUGsYfr0rRpwOryA3d8_dyEkh1ORo', 'rankby': 'distance'}
# ['Falken Apotheke', 'Dr.med.dent. Uwe Ryguschik-Ott Zahnarzt', 'Ev. Johannesstift Wichern-Krankenhaus', 'Marion Fischer Krankengymnastik-Praxis', 'Bernd Wendrich', 'geriavita GmbH', 'Möbius Praxis-EDV und Medizintechnik', 'Wolfgang Lehnig Praxis für Psychotherapie, Supervision und Coaching', 'DaoNatura', 'Wildgehege im Spandauer Forst', 'Evangelisches Johannesstift Behindertenhilfe gGmbH', 'Frau Renate Tranel-Voß', 'Josef Luszpinski Zahnarzt', 'Johannes-Hospiz e.V.', 'Frau Claudia Katharina Wahl-Kammer', 'Margret Latendorf', 'BWS Blindenwohnstätte Spandau', 'NLTeach-Center Berlin', 'Zeltlagerplatz e.V.', 'FINN-BLOCK GmbH']

# %%
params = {'location': ','.join(map(str, [x[50], y[25]])), 
          'types': '|'.join(types),
          'rankby': 'distance',
          'key': key}
r2 = requests.get(base_url, headers=headers, params=params)
res2 = r2.json()
print([elem['name'] for elem in res2['results']])
while 'next_page_token' in res2:
    print('***Got more in this location')
    params['pagetoken'] = res2['next_page_token']
    print(params)
    time.sleep(2)
    r2 = requests.get(base_url, headers=headers, params=params)
    res2 = r2.json()
    print([elem['name'] for elem in res2['results']])
# Out:
# ['Späth-Arboretum', 'Dr. Wolfgang Poswiat', 'Yoga Baumschulenweg', 'KGA Holunderbusch e.V.', 'Kleingartenanlage Ideal III e.V. in Berlin Neukölln', 'Kleingartenanlage Edelweiß Britz e.V.', 'Tierbestattung IM ROSENGARTEN Berlin', 'Georgine Miller', 'Med Pharma Service GmbH', 'Bezirksverband der Kleingärtner e.V.', 'Fit mit Alex', 'Praxis für Physiotherapie und Vitalkosmetik in Berlin Rudow', 'Asmen Ambulanter Pflegedienst GmbH Hayri Saribas', 'Asmen Ambulanter Pflegedienst GmbH', 'Agea Pflegedienst GbR', 'K&K Ambulanz GmbH', 'CORE', 'Heilpraktikerin Antje Bellon', 'Antje Bellon', 'Apotheke Zur Goldenen Kugel']
# ***Got more in this location
# {'location': '52.4513588136,13.4746410256', 'types': 'park|gym|doctor|health|hospital|pharmacy|physiotherapist|spa', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CsQCOgEAAFFjaFK7RXGQ1B6yMIgDj3JiBh-4ubV3_YUUCaMSPrfoO4XvWFuYPYR-4DSlVKzRYulb5UxtlaBRIwW5s_xcK0OcN9gY4ZYTA_JRjFwRVoOd-bgzsYqiaCmwk04JZxmZKBfi859e2elXMfixIv5KgneNT5VN0xg5P_vB8WftreX4LnpOy0MLj44pkN3KTfymypBDRM9GE-L4Gyl-oJuAlYv_c2Lar8iyRrhnvbM58Goc39wFKcR0j8bqUaOEXm5jLN0jzi5GbvFoHvmJCCT-vqKZ7dJlLr46y4r3ABmGg6WIM8smr3YPxdMyHhd8vrBRp0s77h8Du_ohyLd_e3a0qEO-quG3l9gaq4Xz-A4sWYiswln1hAIMtYiXi4_YWeVvDuCieV6T071V4eTCfUlp3ZJJnqHXDGDYUFh4xI6KSuHWEhDM-Lodh7R8Su-Upouqfka9GhR_J-mGmrJZA19NE-wNaMkAhMPMYw', 'rankby': 'distance'}
# ['Drogerie Kussatz GmbH', 'Senioren-Domizil Britz e.K.', 'Seniorenwohnhaus Buschkrug', 'Zur Goldenen Kugel', 'Kiesow Dr. Brinkmann GmbH & Co. KG', 'Aquacentrum-Britz', 'Karl Gläser & Sohn Krankenhausbedarf oHG Nachf. Andreas Gläser e. K.', 'Dres. Manfred Heisse und Barbara Walk', 'HNO-Facharzt', 'Klaus Frey Gesundheitspraktiker für Entspannung und Meditation', 'Esta Koch-Lauer', 'Dr. med. Natalie Klein', 'Privatdozentin Dr. med. Sylke Gellrich', 'Dr.med. Nicholas Hartmann Facharzt für Innere Medizin', 'Herr Behrooz Partow', 'RENAFAN Ambulante Pflege Neukölln', 'Dr. med. Michael Malem', 'Dr. med. Sabine Meyer', 'Witte', 'Dr. Corinna Romann']
# ***Got more in this location
# {'location': '52.4513588136,13.4746410256', 'types': 'park|gym|doctor|health|hospital|pharmacy|physiotherapist|spa', 'key': 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk', 'pagetoken': 'CuQD2gEAAGsahESQjtxbHnDGwDWPq4CY9CHKvnGfK10gPIROY9mnhH7a9AKAGSra9xaWKWpQ5N-hERgkPR5DgFqqNa6yT5gRSXBfKmIbWqcHIFy2asQ3WzvBodRgfUoMoy6sBlZC9VgddZB52JmZNRUKwP7UC2XCoVKXh4_vMxylHYROtkgKRTTLxgupyyzj5bexVlV-8qOHXryzu68bamNbVIc9GcnOMbsHnHtaEgvhX0sN93TCra1RONzugKFQlQnqwzAT8ZYK-QM_01fdTWSGvjOQGT1O7kyU5EvH8qr03P9XLVbnfuxfC10GrFrWiCSm-f_UnjqW88qeXv_CZEprE84wTyKrZTpRsLYo9EX2Ubp0oeB7xRY_pJmtsVMxh6PBsx-vUVOdkUaL1SXX_07N3RSU-48SeLUS_AWqnp4HQTudGcVuSj3IJH2YWA-rdiw5gtkk9_du32V-NI5bSWidNFQQesn2hiYTebQ0p7JzyOccLporwO_-AIbRgYm_DFARLO2afj3AlbVDlIVMvLQhA6JnrQl86mPuRsbNQTPHQdU18hechKBZx-U5BbdH3o4B5mCGlcESEbCjw7dCItwYOavHlyo1lMm5PW1iSYA6cvjD4Da3MFWpwq2nKk3wxtFQmXWuRBIQcaSss2Z5uAK9-haLzOvH-BoUedfdLJ1lLKrM_O5P0HflJdt8lsU', 'rankby': 'distance'}
# ['Dr. Elke Singelmann Zahnärztin', 'Dr.med. Martina Jäger', 'Fontane Apotheke Buckow', 'Martina u. Adler Michael Jäger', 'Dr. med. Michael Adler', 'Fontane Apotheke Buckow Inhaber Katharina Marx e.K.', 'Pfauen Apotheke', 'Praxis für Logopädie Andrea Kruse', 'Kosmetiksalon Magnolia & Dr.Eckstein BioKosmetik Shop Berlin', 'Monika Partow', 'Jautzke', 'Seniorenwohnhaus Haus Leonberg', 'GEERS - Gutes Hören', 'Naturheilpraxis Song', 'Naturheilpraxis Song', 'Dr. Jeanette Salbach', 'Dr.med. Bärbel Wojciechowski', 'Irina Mischke', 'Fiedler Alice Krankengymnastik-Praxis', 'Dr. Ljudmila Jägle']

# %%
# Keys for google API - there's a daily limit of requests
#key = 'AIzaSyCfinjo6dlzYcL9YX5fKca2S0o09DdKT1s' # Helena - off
#key = 'AIzaSyCKMkU3hdi-gUkFJZSuUwWQDxYxYSrHwMc' # Lucia - off
#key = 'AIzaSyAU4IlE0ip3wUbQVgrSdtlg5yNjPFd6XOk' # Danielle
#key = 'AIzaSyDoKn008c-o_llcDcrzpjyd0W1V2_uDgCQ'
#key = 'AIzaSyCNLk5xdCvhOjAsNAV_h_ydEm4Qw9ZutC0'
#key = 'AIzaSyCPBPk08Ev2w-JupF0pj1mRkWt8RXzF-_4'
key = 'AIzaSyAVaZRfFId7y6sZkALNTBO5dQ_2NyTLUFg'

def extract_data(place):
    fields = ['geometry', 'id', 'place_id', 'name', 'types', 'rating', 'vicinity']
    mydict = dict((k,v) for (k,v) in place.items() if k in fields)
    mydict['geometry']['location']['lon'] = mydict['geometry']['location']['lng']
    mydict['geometry']['location'].pop('lng', None)
    if 'viewport' in mydict['geometry']:
        for v in ['northeast', 'southwest']:
            mydict['geometry']['viewport'][v]['lon'] = mydict['geometry']['viewport'][v]['lng']
            mydict['geometry']['viewport'][v].pop('lng', None)
    return mydict

#bulk_data = []
#seen_places_id = set([])

print('Runs.....')
for i, xx in enumerate(x[35:]):
    for j, yy in enumerate(y):
        print('Trying loc ({}, {}): {}'.format(i+35, j, ','.join(map(str, [xx, yy]))))
        
        params = {'location': ','.join(map(str, [xx, yy])), 
                  'types': '|'.join(types),
                  'rankby': 'distance',
                  'key': key}
        
        r = requests.get(base_url, headers=headers, params=params)
        if r.status_code != 200:
            print('Error request. Skip this location')
            continue
        res = r.json()
        #print(res)
        if not res['results']:
            print(res)
        c = 0
        for elem in res['results']:
            if elem['place_id'] in seen_places_id:
                continue
            seen_places_id.add(elem['place_id'])
            bulk_data.append(extract_data(elem))
            c += 1
        print('Added {} elems'.format(c))
            #print('Found: {}'.format(elem['name']))
        while 'next_page_token' in res:
            print('***Got more in this location')
            params = {'location': ','.join(map(str, [xx, yy])), 
                      'types': '|'.join(types),
                      'rankby': 'distance',
                      'key': key,
                      'pagetoken': res['next_page_token']}
            time.sleep(2)
            r = requests.get(base_url, headers=headers, params=params)
            if r.status_code != 200:
                print('Error request. Skip this location')
                continue
            res = r.json()
            if not res['results']:
                print(res)
            c = 0
            for elem in res['results']:
                if elem['place_id'] in seen_places_id:
                    continue
                seen_places_id.add(elem['place_id'])
                bulk_data.append(extract_data(elem))
                c += 1
            print('Added {} elems'.format(c))
        print('\n')
                
print('Last i: {}, j: {}'.format(i, j))
print('Found {} places'.format(len(bulk_data)))
# Out:
# Runs.....
# Trying loc (35, 0): 52.4435582051,13.2035
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 1): 52.4435582051,13.2211241667
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 2): 52.4435582051,13.2387483333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 3): 52.4435582051,13.2563725
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (35, 4): 52.4435582051,13.2739966667
# Added 10 elems
# ***Got more in this location
# Added 14 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (35, 5): 52.4435582051,13.2916208333
# Added 2 elems
# ***Got more in this location
# Added 15 elems
# ***Got more in this location
# Added 13 elems
#
#
# Trying loc (35, 6): 52.4435582051,13.309245
# Added 13 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (35, 7): 52.4435582051,13.3268691667
# Added 4 elems
# ***Got more in this location
# Added 15 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (35, 8): 52.4435582051,13.3444933333
# Added 4 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (35, 9): 52.4435582051,13.3621175
# Added 0 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 13 elems
#
#
# Trying loc (35, 10): 52.4435582051,13.3797416667
# Added 7 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (35, 11): 52.4435582051,13.3973658333
# Added 1 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (35, 12): 52.4435582051,13.41499
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (35, 13): 52.4435582051,13.4326141667
# Added 1 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (35, 14): 52.4435582051,13.4502383333
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (35, 15): 52.4435582051,13.4678625
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (35, 16): 52.4435582051,13.4854866667
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 8 elems
#
#
# Trying loc (35, 17): 52.4435582051,13.5031108333
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 18): 52.4435582051,13.520735
# Added 1 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 19): 52.4435582051,13.5383591667
# Added 0 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (35, 20): 52.4435582051,13.5559833333
# Added 0 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (35, 21): 52.4435582051,13.5736075
# Added 9 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (35, 22): 52.4435582051,13.5912316667
# Added 0 elems
# ***Got more in this location
# Added 14 elems
# ***Got more in this location
# Added 17 elems
#
#
# Trying loc (35, 23): 52.4435582051,13.6088558333
# Added 2 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (35, 24): 52.4435582051,13.62648
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (36, 0): 52.4395561538,13.2035
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (36, 1): 52.4395561538,13.2211241667
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (36, 2): 52.4395561538,13.2387483333
# Added 12 elems
# ***Got more in this location
# Added 11 elems
# ***Got more in this location
# Added 13 elems
#
#
# Trying loc (36, 3): 52.4395561538,13.2563725
# Added 4 elems
# ***Got more in this location
# Added 17 elems
# ***Got more in this location
# Added 20 elems
#
#
# Trying loc (36, 4): 52.4395561538,13.2739966667
# Added 2 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (36, 5): 52.4395561538,13.2916208333
# Added 15 elems
# ***Got more in this location
# Added 9 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (36, 6): 52.4395561538,13.309245
# Added 8 elems
# ***Got more in this location
# Added 12 elems
# ***Got more in this location
# Added 18 elems
#
#
# Trying loc (36, 7): 52.4395561538,13.3268691667
# Added 5 elems
# ***Got more in this location
# Added 6 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (36, 8): 52.4395561538,13.3444933333
# Added 11 elems
# ***Got more in this location
# Added 20 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (36, 9): 52.4395561538,13.3621175
# Added 0 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (36, 10): 52.4395561538,13.3797416667
# Added 10 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 13 elems
#
#
# Trying loc (36, 11): 52.4395561538,13.3973658333
# Added 1 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (36, 12): 52.4395561538,13.41499
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (36, 13): 52.4395561538,13.4326141667
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (36, 14): 52.4395561538,13.4502383333
# Added 1 elems
# ***Got more in this location
# Added 9 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (36, 15): 52.4395561538,13.4678625
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (36, 16): 52.4395561538,13.4854866667
# Added 0 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (36, 17): 52.4395561538,13.5031108333
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (36, 18): 52.4395561538,13.520735
# Added 4 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (36, 19): 52.4395561538,13.5383591667
# Added 1 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (36, 20): 52.4395561538,13.5559833333
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (36, 21): 52.4395561538,13.5736075
# Added 4 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (36, 22): 52.4395561538,13.5912316667
# Added 1 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (36, 23): 52.4395561538,13.6088558333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (36, 24): 52.4395561538,13.62648
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (37, 0): 52.4355541026,13.2035
# Added 1 elems
# ***Got more in this location
# Added 10 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (37, 1): 52.4355541026,13.2211241667
# Added 8 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (37, 2): 52.4355541026,13.2387483333
# Added 7 elems
# ***Got more in this location
# Added 6 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (37, 3): 52.4355541026,13.2563725
# Added 14 elems
# ***Got more in this location
# Added 12 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (37, 4): 52.4355541026,13.2739966667
# Added 1 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 14 elems
#
#
# Trying loc (37, 5): 52.4355541026,13.2916208333
# Added 7 elems
# ***Got more in this location
# Added 14 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (37, 6): 52.4355541026,13.309245
# Added 11 elems
# ***Got more in this location
# Added 6 elems
# ***Got more in this location
# Added 8 elems
#
#
# Trying loc (37, 7): 52.4355541026,13.3268691667
# Added 5 elems
# ***Got more in this location
# Added 10 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (37, 8): 52.4355541026,13.3444933333
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 14 elems
#
#
# Trying loc (37, 9): 52.4355541026,13.3621175
# Added 0 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (37, 10): 52.4355541026,13.3797416667
# Added 2 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (37, 11): 52.4355541026,13.3973658333
# Added 3 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (37, 12): 52.4355541026,13.41499
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (37, 13): 52.4355541026,13.4326141667
# Added 0 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 8 elems
#
#
# Trying loc (37, 14): 52.4355541026,13.4502383333
# Added 4 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (37, 15): 52.4355541026,13.4678625
# Added 8 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (37, 16): 52.4355541026,13.4854866667
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (37, 17): 52.4355541026,13.5031108333
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (37, 18): 52.4355541026,13.520735
# Added 1 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 19 elems
#
#
# Trying loc (37, 19): 52.4355541026,13.5383591667
# Added 2 elems
# ***Got more in this location
# Added 16 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (37, 20): 52.4355541026,13.5559833333
# Added 2 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (37, 21): 52.4355541026,13.5736075
# Added 3 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (37, 22): 52.4355541026,13.5912316667
# Added 3 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (37, 23): 52.4355541026,13.6088558333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (37, 24): 52.4355541026,13.62648
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (38, 0): 52.4315520513,13.2035
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (38, 1): 52.4315520513,13.2211241667
# Added 5 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 18 elems
#
#
# Trying loc (38, 2): 52.4315520513,13.2387483333
# Added 3 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (38, 3): 52.4315520513,13.2563725
# Added 20 elems
# ***Got more in this location
# Added 20 elems
# ***Got more in this location
# Added 20 elems
#
#
# Trying loc (38, 4): 52.4315520513,13.2739966667
# Added 8 elems
# ***Got more in this location
# Added 9 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (38, 5): 52.4315520513,13.2916208333
# Added 5 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (38, 6): 52.4315520513,13.309245
# Added 2 elems
# ***Got more in this location
# Added 14 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (38, 7): 52.4315520513,13.3268691667
# Added 4 elems
# ***Got more in this location
# Added 20 elems
# ***Got more in this location
# Added 17 elems
#
#
# Trying loc (38, 8): 52.4315520513,13.3444933333
# Added 5 elems
# ***Got more in this location
# Added 11 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (38, 9): 52.4315520513,13.3621175
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 14 elems
#
#
# Trying loc (38, 10): 52.4315520513,13.3797416667
# Added 1 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (38, 11): 52.4315520513,13.3973658333
# Added 2 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (38, 12): 52.4315520513,13.41499
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (38, 13): 52.4315520513,13.4326141667
# Added 0 elems
# ***Got more in this location
# Added 15 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (38, 14): 52.4315520513,13.4502383333
# Added 13 elems
# ***Got more in this location
# Added 12 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (38, 15): 52.4315520513,13.4678625
# Added 6 elems
# ***Got more in this location
# Added 18 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (38, 16): 52.4315520513,13.4854866667
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 15 elems
#
#
# Trying loc (38, 17): 52.4315520513,13.5031108333
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (38, 18): 52.4315520513,13.520735
# Added 4 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (38, 19): 52.4315520513,13.5383591667
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (38, 20): 52.4315520513,13.5559833333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (38, 21): 52.4315520513,13.5736075
# Added 11 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (38, 22): 52.4315520513,13.5912316667
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (38, 23): 52.4315520513,13.6088558333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (38, 24): 52.4315520513,13.62648
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (39, 0): 52.42755,13.2035
# Added 4 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (39, 1): 52.42755,13.2211241667
# Added 1 elems
# ***Got more in this location
# Added 9 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (39, 2): 52.42755,13.2387483333
# Added 9 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (39, 3): 52.42755,13.2563725
# Added 6 elems
# ***Got more in this location
# Added 9 elems
# ***Got more in this location
# Added 7 elems
#
#
# Trying loc (39, 4): 52.42755,13.2739966667
# Added 2 elems
# ***Got more in this location
# Added 6 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (39, 5): 52.42755,13.2916208333
# Added 1 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (39, 6): 52.42755,13.309245
# Added 0 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (39, 7): 52.42755,13.3268691667
# Added 17 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 10 elems
#
#
# Trying loc (39, 8): 52.42755,13.3444933333
# Added 10 elems
# ***Got more in this location
# Added 7 elems
# ***Got more in this location
# Added 11 elems
#
#
# Trying loc (39, 9): 52.42755,13.3621175
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 6 elems
#
#
# Trying loc (39, 10): 52.42755,13.3797416667
# Added 3 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (39, 11): 52.42755,13.3973658333
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (39, 12): 52.42755,13.41499
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (39, 13): 52.42755,13.4326141667
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 5 elems
#
#
# Trying loc (39, 14): 52.42755,13.4502383333
# Added 1 elems
# ***Got more in this location
# Added 5 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (39, 15): 52.42755,13.4678625
# Added 1 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 9 elems
#
#
# Trying loc (39, 16): 52.42755,13.4854866667
# Added 0 elems
# ***Got more in this location
# Added 3 elems
# ***Got more in this location
# Added 13 elems
#
#
# Trying loc (39, 17): 52.42755,13.5031108333
# Added 0 elems
# ***Got more in this location
# Added 14 elems
# ***Got more in this location
# Added 14 elems
#
#
# Trying loc (39, 18): 52.42755,13.520735
# Added 0 elems
# ***Got more in this location
# Added 2 elems
# ***Got more in this location
# Added 2 elems
#
#
# Trying loc (39, 19): 52.42755,13.5383591667
# Added 1 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 1 elems
#
#
# Trying loc (39, 20): 52.42755,13.5559833333
# Added 0 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 4 elems
#
#
# Trying loc (39, 21): 52.42755,13.5736075
# Added 0 elems
# ***Got more in this location
# Added 8 elems
# ***Got more in this location
# Added 12 elems
#
#
# Trying loc (39, 22): 52.42755,13.5912316667
# Added 0 elems
# ***Got more in this location
# Added 4 elems
# ***Got more in this location
# Added 3 elems
#
#
# Trying loc (39, 23): 52.42755,13.6088558333
# Added 0 elems
# ***Got more in this location
# Added 0 elems
# ***Got more in this location
# Added 0 elems
#
#
# Trying loc (39, 24): 52.42755,13.62648
# Added 2 elems
# ***Got more in this location
# Added 1 elems
# ***Got more in this location
# Added 1 elems
#
#
# Last i: 4, j: 24
# Found 18232 places

# %%
len(set([elem['name'] for elem  in bulk_data]))
# Out:
# 17485

# %%
bulk_data_bk = bulk_data
seen_places_id_bk = seen_places_id

# %%
len(bulk_data)
# Out:
# 18232

# %%
bulk_data[0]
# Out:
# {'geometry': {'location': {'lat': 52.5847644, 'lon': 13.2114144}},
#  'id': '8b793795c49aded166bfa6385c8e571b3b559ae7',
#  'name': 'DLRG Wasserrettungsstation Bürgerablage',
#  'place_id': 'ChIJVd6Pzu1VqEcRu3VEZvdYLIU',
#  'types': ['health', 'point_of_interest', 'establishment'],
#  'vicinity': 'Niederneuendorfer Allee 79, Berlin'}

# %%
# Postprocess data to store keyword
def post_proc(place, keyword=None):
    types = ['park', 'gym', 'doctor', 'health', 
             'hospital', 'pharmacy', 'physiotherapist', 'spa']
    place['keyword'] = keyword if keyword else [p for p in place['types'] if p in types][0]
    return place

# %%
bulk_data = [post_proc(el) for el in bulk_data]
bulk_data[1]
# Out:
# {'geometry': {'location': {'lat': 52.581187, 'lon': 13.212754}},
#  'id': '6d128537896cf0fea84c51cdf98489c4e9c3a4bb',
#  'keyword': 'park',
#  'name': 'Berliner Camping Club e. V. - Platz Bürgerablage',
#  'place_id': 'ChIJpWqwV-lVqEcRvJociwxCGIc',
#  'types': ['campground',
#   'rv_park',
#   'park',
#   'lodging',
#   'point_of_interest',
#   'establishment'],
#  'vicinity': 'Niederneuendorfer Allee 63, Berlin'}

# %%
fo = open('bulk_data_type.json', 'w')
fo.write(json.dumps(bulk_data))
fo.close()

# %%
bulk_data_ff = json.loads(open('bulk_data_type.json').read())
bulk_data_ff[0]
# Out:
# {'geometry': {'location': {'lat': 52.5847644, 'lon': 13.2114144}},
#  'id': '8b793795c49aded166bfa6385c8e571b3b559ae7',
#  'keyword': 'health',
#  'name': 'DLRG Wasserrettungsstation Bürgerablage',
#  'place_id': 'ChIJVd6Pzu1VqEcRu3VEZvdYLIU',
#  'types': ['health', 'point_of_interest', 'establishment'],
#  'vicinity': 'Niederneuendorfer Allee 79, Berlin'}

# %%
# Query with keywords - No need for such fine grid
# Box is ~30km x 20km. Sample every ~1 km
cnt_x = 10
cnt_y = 5
x = np.linspace(nw[0], se[0], cnt_x)
y = np.linspace(nw[1], se[1], cnt_y)

# %%
keywords = ['vegan', 'hallenbad', 'freibad', 'schwimmhalle', 'pilates', 'yoga', 'fitness', 
            'crossfit', 'training', 'sportverein', 'skatepark', 'zumba', 'tanzschule', 
            'klettern', 'bouldern', 'kampfsport' ]

# %%
# Keys for google API - there's a daily limit of requests
#key = 'AIzaSyAVaZRfFId7y6sZkALNTBO5dQ_2NyTLUFg'
key = 'AIzaSyAt6n32tLD6ChLsZ8KtZh09xiVH4Wg4ZWc'

#bulk_data_kw = []
#seen_places_id_kw = seen_places_id

kw = keywords[15]

print('Runs for keyword {}...'.format(kw))
for i, xx in enumerate(x):
    for j, yy in enumerate(y):
        print('Trying loc ({}, {}): {}'.format(i, j, ','.join(map(str, [xx, yy]))))
        
        params = {'location': ','.join(map(str, [xx, yy])), 
                  'keyword': kw,
                  'rankby': 'distance',
                  'key': key}
        
        r = requests.get(base_url, headers=headers, params=params)
        if r.status_code != 200:
            print('Error request. Skip this location')
            continue
        res = r.json()
        #print(res)
        if not res['results']:
            print(res)
        c = 0
        for elem in res['results']:
            if elem['place_id'] in seen_places_id_kw:
                continue
            seen_places_id_kw.add(elem['place_id'])
            bulk_data_kw.append(post_proc(extract_data(elem), kw))
            c += 1
        print('Added {} elems from {} found'.format(c, len(res['results'])))
        while 'next_page_token' in res:
            print('***Got more in this location')
            params = {'location': ','.join(map(str, [xx, yy])), 
                      'types': '|'.join(types),
                      'rankby': 'distance',
                      'key': key,
                      'pagetoken': res['next_page_token']}
            time.sleep(2)
            r = requests.get(base_url, headers=headers, params=params)
            if r.status_code != 200:
                print('Error request. Skip this location')
                continue
            res = r.json()
            if not res['results']:
                print(res)
            c = 0
            for elem in res['results']:
                if elem['place_id'] in seen_places_id_kw:
                    continue
                seen_places_id_kw.add(elem['place_id'])
                bulk_data_kw.append(post_proc(extract_data(elem), kw))
                c += 1
            print('Added {} elems from {} found'.format(c, len(res['results'])))
                
print('Last i: {}, j: {}'.format(i, j))
print('Found {} places'.format(len([el for el in bulk_data_kw if el['keyword']==kw])))
# Out:
# Runs for keyword kampfsport...
# Trying loc (0, 0): 52.58363,13.2035
# Added 6 elems from 20 found
# ***Got more in this location
# Added 5 elems from 11 found
# Trying loc (0, 1): 52.58363,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 3 elems from 16 found
# Trying loc (0, 2): 52.58363,13.41499
# Added 4 elems from 20 found
# ***Got more in this location
# Added 1 elems from 18 found
# Trying loc (0, 3): 52.58363,13.520735
# Added 2 elems from 20 found
# ***Got more in this location
# Added 2 elems from 20 found
# ***Got more in this location
# Added 0 elems from 4 found
# Trying loc (0, 4): 52.58363,13.62648
# Added 1 elems from 20 found
# ***Got more in this location
# Added 1 elems from 20 found
# Trying loc (1, 0): 52.5662877778,13.2035
# Added 1 elems from 20 found
# ***Got more in this location
# Added 1 elems from 13 found
# Trying loc (1, 1): 52.5662877778,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 3 elems from 20 found
# ***Got more in this location
# Added 0 elems from 4 found
# Trying loc (1, 2): 52.5662877778,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (1, 3): 52.5662877778,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 2 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (1, 4): 52.5662877778,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (2, 0): 52.5489455556,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 16 found
# Trying loc (2, 1): 52.5489455556,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (2, 2): 52.5489455556,13.41499
# Added 2 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# Trying loc (2, 3): 52.5489455556,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (2, 4): 52.5489455556,13.62648
# Added 1 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (3, 0): 52.5316033333,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (3, 1): 52.5316033333,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (3, 2): 52.5316033333,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# Trying loc (3, 3): 52.5316033333,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 3 found
# Trying loc (3, 4): 52.5316033333,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# Trying loc (4, 0): 52.5142611111,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (4, 1): 52.5142611111,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (4, 2): 52.5142611111,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 6 found
# Trying loc (4, 3): 52.5142611111,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 3 found
# Trying loc (4, 4): 52.5142611111,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 19 found
# Trying loc (5, 0): 52.4969188889,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (5, 1): 52.4969188889,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (5, 2): 52.4969188889,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 2 found
# Trying loc (5, 3): 52.4969188889,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# Trying loc (5, 4): 52.4969188889,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 17 found
# Trying loc (6, 0): 52.4795766667,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 15 found
# Trying loc (6, 1): 52.4795766667,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (6, 2): 52.4795766667,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 5 found
# Trying loc (6, 3): 52.4795766667,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 19 found
# Trying loc (6, 4): 52.4795766667,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (7, 0): 52.4622344444,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 14 found
# Trying loc (7, 1): 52.4622344444,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 16 found
# Trying loc (7, 2): 52.4622344444,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 18 found
# Trying loc (7, 3): 52.4622344444,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 18 found
# Trying loc (7, 4): 52.4622344444,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 20 found
# Trying loc (8, 0): 52.4448922222,13.2035
# Added 1 elems from 20 found
# ***Got more in this location
# Added 1 elems from 17 found
# Trying loc (8, 1): 52.4448922222,13.309245
# Added 1 elems from 20 found
# ***Got more in this location
# Added 0 elems from 15 found
# Trying loc (8, 2): 52.4448922222,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 19 found
# Trying loc (8, 3): 52.4448922222,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 16 found
# Trying loc (8, 4): 52.4448922222,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 2 elems from 17 found
# Trying loc (9, 0): 52.42755,13.2035
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 16 found
# Trying loc (9, 1): 52.42755,13.309245
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 15 found
# Trying loc (9, 2): 52.42755,13.41499
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 19 found
# Trying loc (9, 3): 52.42755,13.520735
# Added 0 elems from 20 found
# ***Got more in this location
# Added 0 elems from 17 found
# Trying loc (9, 4): 52.42755,13.62648
# Added 0 elems from 20 found
# ***Got more in this location
# Added 1 elems from 16 found
# Last i: 9, j: 4
# Found 46 places

# %%
len([el for el in bulk_data_kw if el['keyword']==kw])
# Out:
# 46

# %%
len(bulk_data_kw)
# Out:
# 1268

# %%
fo = open('bulk_data_kw.json', 'w')
fo.write(json.dumps(bulk_data_kw))
fo.close()
